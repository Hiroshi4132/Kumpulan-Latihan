# %% [markdown]
# <a href="https://colab.research.google.com/github/Hiroshi4132/Kumpulan-Latihan/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list = []
for i in range(10):
  number = int(input("input angka : "))
  my_list.append(number)
# Out:
# input angka : 3
# input angka : 5
# input angka : 7
# input angka : 3
# input angka : 9
# input angka : 4
# input angka : 2
# input angka : 7
# input angka : 3
# input angka : 6

# %% [markdown]
# Menampilkan Data List, Nilai tertinggi, Terendah dan rata-rata

# %%
print("list angka:", list)
print("nilai tertinggi: ", max(my_list))
print("nilai terendah: ", min(my_list))
print("nilai rata-rata: ", sum(my_list))
# Out:
# list angka: <class 'list'>
# nilai tertinggi:  9
# nilai terendah:  2
# nilai rata-rata:  49
